# %%
# !pip install pymongo pandas
# Out:
# Requirement already satisfied: pymongo in /usr/local/python/3.11.15/lib/python3.11/site-packages (4.16.0)
# Requirement already satisfied: pandas in /usr/local/python/3.11.15/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in /usr/local/python/3.11.15/lib/python3.11/site-packages (from pymongo) (2.8.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.11.15/lib/python3.11/site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/python/3.11.15/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/python/3.11.15/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime

# %%
client = MongoClient("mongodb://root:rootpass@localhost:27017")
print(client.server_info()["version"])
# Out:
# 8.2.6

# %%
db = client['loja']
colecao = db['vendas']

# %%
dados = [ { "cliente": "Ana", "produto": "Mouse", "categoria": "Informática", "quantidade": 2, "preco_unitario": 50, "cidade": "Ourinhos", "data": datetime(2026, 3, 1), "forma_pagamento": "Cartão" }, { "cliente": "Bruno", "produto": "Teclado", "categoria": "Informática", "quantidade": 1, "preco_unitario": 120, "cidade": "Jacarezinho", "data": datetime(2026, 3, 2), "forma_pagamento": "Pix" }, { "cliente": "Carla", "produto": "Caderno", "categoria": "Papelaria", "quantidade": 5, "preco_unitario": 15, "cidade": "Ourinhos", "data": datetime(2026, 3, 2), "forma_pagamento": "Dinheiro" }, { "cliente": "Daniel", "produto": "Caneta", "categoria": "Papelaria", "quantidade": 10, "preco_unitario": 3, "cidade": "Salto Grande", "data": datetime(2026, 3, 3), "forma_pagamento": "Pix" }, { "cliente": "Elaine", "produto": "Monitor", "categoria": "Informática", "quantidade": 1, "preco_unitario": 900, "cidade": "Ourinhos", "data": datetime(2026, 3, 3), "forma_pagamento": "Cartão" }, { "cliente": "Fabio", "produto": "Mochila", "categoria": "Acessórios", "quantidade": 2, "preco_unitario": 80, "cidade": "Jacarezinho", "data": datetime(2026, 3, 4), "forma_pagamento": "Boleto" }, { "cliente": "Gabriela", "produto": "Livro", "categoria": "Livros", "quantidade": 3, "preco_unitario": 40, "cidade": "Ourinhos", "data": datetime(2026, 3, 4), "forma_pagamento": "Pix" }, { "cliente": "Henrique", "produto": "Fone", "categoria": "Informática", "quantidade": 2, "preco_unitario": 150, "cidade": "Assis", "data": datetime(2026, 3, 5), "forma_pagamento": "Cartão" }, { "cliente": "Isabela", "produto": "Agenda", "categoria": "Papelaria", "quantidade": 4, "preco_unitario": 20, "cidade": "Salto Grande", "data": datetime(2026, 3, 5), "forma_pagamento": "Dinheiro" }, { "cliente": "João", "produto": "Webcam", "categoria": "Informática", "quantidade": 1, "preco_unitario": 250, "cidade": "Ourinhos", "data": datetime(2026, 3, 6), "forma_pagamento": "Pix" } ]

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69bc9b01b3742879b4126839'), ObjectId('69bc9b01b3742879b412683a'), ObjectId('69bc9b01b3742879b412683b'), ObjectId('69bc9b01b3742879b412683c'), ObjectId('69bc9b01b3742879b412683d'), ObjectId('69bc9b01b3742879b412683e'), ObjectId('69bc9b01b3742879b412683f'), ObjectId('69bc9b01b3742879b4126840'), ObjectId('69bc9b01b3742879b4126841'), ObjectId('69bc9b01b3742879b4126842')], acknowledged=True)

# %%
dados_mongo = list(colecao.find({
    "preco_unitario": {"$gte" : 100, "$lte" : 300}}))

display(dados_mongo)
# Out:
# [{'_id': ObjectId('69bc9919501abd56118da8e8'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69bc9919501abd56118da8ee'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69bc9919501abd56118da8f0'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69bc9b01b3742879b412683a'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69bc9b01b3742879b4126840'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69bc9b01b3742879b4126842'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
dados_mongo = list(colecao.find({
    "cidade": {"$in" : ["Ourinhos", "Assis"]}}))

display(dados_mongo)
# Out:
# [{'_id': ObjectId('69bc9919501abd56118da8e7'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69bc9919501abd56118da8e9'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69bc9919501abd56118da8eb'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69bc9919501abd56118da8ed'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69bc9919501abd56118da8ee'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69bc9919501abd56118da8f0'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69bc9b01b3742879b4126839'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69bc9b01b3742879b412683b'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69bc9b01b3742879b412683d'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69bc9b01b3742879b412683f'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69bc9b01b3742879b4126840'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69bc9b01b3742879b4126842'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
df = pd.DataFrame(dados_mongo)
df
# Out:
#                          _id   cliente  produto    categoria  quantidade  \
# 0   69bc9919501abd56118da8e7       Ana    Mouse  Informática           2
# 1   69bc9919501abd56118da8e9     Carla  Caderno    Papelaria           5
# 2   69bc9919501abd56118da8eb    Elaine  Monitor  Informática           1
# 3   69bc9919501abd56118da8ed  Gabriela    Livro       Livros           3
# 4   69bc9919501abd56118da8ee  Henrique     Fone  Informática           2
# 5   69bc9919501abd56118da8f0      João   Webcam  Informática           1
# 6   69bc9b01b3742879b4126839       Ana    Mouse  Informática           2
# 7   69bc9b01b3742879b412683b     Carla  Caderno    Papelaria           5
# 8   69bc9b01b3742879b412683d    Elaine  Monitor  Informática           1
# 9   69bc9b01b3742879b412683f  Gabriela    Livro       Livros           3
# 10  69bc9b01b3742879b4126840  Henrique     Fone  Informática           2
# 11  69bc9b01b3742879b4126842      João   Webcam  Informática           1
#
#     preco_unitario    cidade       data forma_pagamento
# 0               50  Ourinhos 2026-03-01          Cartão
# 1               15  Ourinhos 2026-03-02        Dinheiro
# 2              900  Ourinhos 2026-03-03          Cartão
# 3               40  Ourinhos 2026-03-04             Pix
# 4              150     Assis 2026-03-05          Cartão
# 5              250  Ourinhos 2026-03-06             Pix
# 6               50  Ourinhos 2026-03-01          Cartão
# 7               15  Ourinhos 2026-03-02        Dinheiro
# 8              900  Ourinhos 2026-03-03          Cartão
# 9               40  Ourinhos 2026-03-04             Pix
# 10             150     Assis 2026-03-05          Cartão
# 11             250  Ourinhos 2026-03-06             Pix

# %%
df.isnull().sum()
# Out:
# _id                0
# cliente            0
# produto            0
# categoria          0
# quantidade         0
# preco_unitario     0
# cidade             0
# data               0
# forma_pagamento    0
# dtype: int64

# %%
df["valor_total"] = df['quantidade'] * df['preco_unitario']
df.head(5)
# Out:
#                         _id   cliente  produto    categoria  quantidade  \
# 0  69bc9919501abd56118da8e7       Ana    Mouse  Informática           2
# 1  69bc9919501abd56118da8e9     Carla  Caderno    Papelaria           5
# 2  69bc9919501abd56118da8eb    Elaine  Monitor  Informática           1
# 3  69bc9919501abd56118da8ed  Gabriela    Livro       Livros           3
# 4  69bc9919501abd56118da8ee  Henrique     Fone  Informática           2
#
#    preco_unitario    cidade       data forma_pagamento  valor_total
# 0              50  Ourinhos 2026-03-01          Cartão          100
# 1              15  Ourinhos 2026-03-02        Dinheiro           75
# 2             900  Ourinhos 2026-03-03          Cartão          900
# 3              40  Ourinhos 2026-03-04             Pix          120
# 4             150     Assis 2026-03-05          Cartão          300

# %%
faturamento = df["valor_total"].sum()
print('Faturamento Total: ', faturamento)
# Out:
# Faturamento Total:  3490

# %%
faturamento_categoria = df.groupby('categoria') ['valor_total'].sum().sort_values(ascending=False)
faturamento_categoria
# Out:
# categoria
# Informática    3100
# Livros          240
# Papelaria       150
# Name: valor_total, dtype: int64

# %%
faturamento_produto = df.groupby('produto')['valor_total'].sum().sort_values(ascending=False)
faturamento_produto
# Out:
# produto
# Monitor    1800
# Fone        600
# Webcam      500
# Livro       240
# Mouse       200
# Caderno     150
# Name: valor_total, dtype: int64

# %%
vendas_por_cidade = df['cidade'].value_counts()
vendas_por_cidade
# Out:
# cidade
# Ourinhos    10
# Assis        2
# Name: count, dtype: int64

# %%
media_valor_vendas = df['valor_total'].mean()
print(f"Média do valor das vendas: {media_valor_vendas:.2f}")
# Out:
# Média do valor das vendas: 290.83

# %%
produto_top = df.groupby("produto")['valor_total'].sum().idxmax()
produto_top
# Out:
# 'Monitor'

# %%
cidade_top = df['cidade'].value_counts().idxmax()
cidade_top
# Out:
# 'Ourinhos'

# %%
relatorio = {
"data_geracao" : datetime.now(),
"faturamento_total": float(faturamento),
"faturamento_categoria" : faturamento_categoria.to_dict,
"produto_top" : produto_top,
"cidade_top" : cidade_top
}

display(relatorio)
# Out:
# {'data_geracao': datetime.datetime(2026, 3, 20, 1, 36, 44, 831467),
#  'faturamento_total': 3490.0,
#  'faturamento_categoria': <bound method Series.to_dict of categoria
#  Informática    3100
#  Livros          240
#  Papelaria       150
#  Name: valor_total, dtype: int64>,
#  'produto_top': 'Monitor',
#  'cidade_top': 'Ourinhos'}

# %%
colecao_relatorios = db['relatorios']
colecao_relatorios.insert_one(relatorio)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# Cell In[55], line 2
#       1 colecao_relatorios = db['relatorios']
# ----> 2 colecao_relatorios.insert_one(relatorio)
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)    826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2083, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2069 """Execute an operation with consecutive retries if possible
#    2070
#    2071 Returns func()'s return value on success. On error retries the same
#    (...)   2080 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2081 """
#    2082 with self._tmp_session(session) as s:
# -> 2083     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2895, in _ClientConnectionRetryable._write(self)
#    2887         if self._retrying:
#    2888             _debug_log(
#    2889                 _COMMAND_LOGGER,
#    2890                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)   2893                 operationId=self._operation_id,
#    2894             )
# -> 2895         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2896 except PyMongoError as exc:
#    2897     if not self._retryable:
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/collection.py:819, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     816 if bypass_doc_val is not None:
#     817     command["bypassDocumentValidation"] = bypass_doc_val
# --> 819 result = conn.command(
#     820     self._database.name,
#     821     command,
#     822     write_concern=write_concern,
#     823     codec_options=self._write_response_codec_options,
#     824     session=session,
#     825     client=self._database.client,
#     826     retryable_write=retryable_write,
#     827 )
#     829 _check_write_command_response(result)
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/pool.py:426, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     424 # Catch socket.error, KeyboardInterrupt, CancelledError, etc. and close ourselves.
#     425 except BaseException as error:
# --> 426     self._raise_connection_failure(error)
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/pool.py:398, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     396     self._raise_if_not_writable(unacknowledged)
#     397 try:
# --> 398     return command(
#     399         self,
#     400         dbname,
#     401         spec,
#     402         self.is_mongos,
#     403         read_preference,
#     404         codec_options,  # type: ignore[arg-type]
#     405         session,
#     406         client,
#     407         check,
#     408         allowable_errors,
#     409         self.address,
#     410         listeners,
#     411         self.max_bson_size,
#     412         read_concern,
#     413         parse_write_concern_error=parse_write_concern_error,
#     414         collation=collation,
#     415         compression_ctx=self.compression_context,
#     416         use_op_msg=self.op_msg_enabled,
#     417         unacknowledged=unacknowledged,
#     418         user_fields=user_fields,
#     419         exhaust_allowed=exhaust_allowed,
#     420         write_concern=write_concern,
#     421     )
#     422 except (OperationFailure, NotPrimaryError):
#     423     raise
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/synchronous/network.py:148, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     146 flags = _OpMsg.MORE_TO_COME if unacknowledged else 0
#     147 flags |= _OpMsg.EXHAUST_ALLOWED if exhaust_allowed else 0
# --> 148 request_id, msg, size, max_doc_size = message._op_msg(
#     149     flags, spec, dbname, read_preference, codec_options, ctx=compression_ctx
#     150 )
#     151 # If this is an unacknowledged write then make sure the encoded doc(s)
#     152 # are small enough, otherwise rely on the server to return an error.
#     153 if unacknowledged and max_bson_size is not None and max_doc_size > max_bson_size:
#
# File /usr/local/python/3.11.15/lib/python3.11/site-packages/pymongo/message.py:419, in _op_msg(flags, command, dbname, read_preference, opts, ctx)
#     417     if ctx:
#     418         return _op_msg_compressed(flags, command, identifier, docs, opts, ctx)
# --> 419     return _op_msg_uncompressed(flags, command, identifier, docs, opts)
#     420 finally:
#     421     # Add the field back to the command.
#     422     if identifier:
#
# InvalidDocument: Invalid document: cannot encode object: <bound method Series.to_dict of categoria
# Informática    3100
# Livros          240
# Papelaria       150
# Name: valor_total, dtype: int64>, of type: <class 'method'>

# %%
for r in colecao_relatorios.find():
    display(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 for r in colecao_relatorios.find():
#       2     display(r)
#
# NameError: name 'colecao_relatorios' is not defined
